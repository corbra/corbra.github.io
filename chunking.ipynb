# %%
import tensorflow as tf

import zipfile
import pandas as pd
import sys
#import dask.dataframe as dd
from tqdm import tqdm

# %%
# #mount folder
# from google.colab import drive
# drive.mount('/content/gdrive')

# # go to folder location
# %cd /content/gdrive/MyDrive/projects/Incognito/

# ! pip install dask[dataframe]
# ! pip install -U tqdm



# column_names = ['created'	,'name'	,'productclass',	'serial',	'value']

# with zipfile.ZipFile(zipfile1, 'r') as z:
#   with z.open("Jan26_Data.txt") as f:
#     dataset = tf.data.experimental.make_csv_dataset(f,batch_size=2,field_delim='/')

# %%
import numpy as np

#created	name	productclass	serial	value

zipfile1 = 'Jan26_Data.txt.zip'

filename = 'Jan26_Data.txt'

# %cd /Users/cormacbracken/Projects/Incognito

# parameter_defaults = {
# 'Serial':'1',
# 'Timestamp':'2',
# 'MODEL':'3',
# 'PRODUCT_CLASS':'4',
# 'FIRMWARE_VERSION':'5',
# 'TOTAL_UPTIME':'6',
# 'IMEI':'7',
# 'IMSI':'8'
# ,'CELL_ID':'9',
# 'ENODEB_ID':'10',
# 'LAC':'11'
# ,'PCI':'12',
# 'DOWNSTREAM_RATE':'13',
# 'UPSTREAM_RATE':'14',
# 'PLMN':'15',
# 'RSRP':'16',
# 'RSRQ':'17',
# 'RSSI':'18',
# 'SINR':'19',
# 'SIGNAL_QUALITY':'20',
# 'BYTES_RECEIVED':'21',
# 'BYTES_SENT':'22',
# 'ROAM_STATUS':'23',
# 'SERVICE_STATUS':'24',
# 'CONNECTED_DEVICES_WAN':'25',
# 'CONNECTED_DEVICES_LAN':'26',
# 'NETWORK_PRIORITY':'27',
# 'EXTERNAL_ANTENNA1':'28',
# 'EXTERNAL_ANTENNA2':'29'
# }


parameter_defaults = {
'Serial':np.nan,
'Timestamp':np.nan,
'MODEL':np.nan,
'PRODUCT_CLASS':np.nan,
'FIRMWARE_VERSION':np.nan,
'TOTAL_UPTIME':np.nan,
'IMEI':np.nan,
'IMSI':np.nan,
'CELL_ID':np.nan,
'ENODEB_ID':np.nan,
'LAC':np.nan,
'PCI':np.nan,
'DOWNSTREAM_RATE':np.nan,
'UPSTREAM_RATE':np.nan,
'PLMN':np.nan,
'RSRP':np.nan,
'RSRQ':np.nan,
'RSSI':np.nan,
'SINR':np.nan,
'SIGNAL_QUALITY':np.nan,
'BYTES_RECEIVED':np.nan,
'BYTES_SENT':np.nan,
'ROAM_STATUS':np.nan,
'SERVICE_STATUS':np.nan,
'CONNECTED_DEVICES_WAN':np.nan,
'CONNECTED_DEVICES_LAN':np.nan,
'NETWORK_PRIORITY':np.nan,
'EXTERNAL_ANTENNA1':np.nan,
'EXTERNAL_ANTENNA2':np.nan
}

map_Y687_060 = {
 'InternetGatewayDevice.DeviceInfo.SerialNumber':'Serial',
#'':'Timestamp',
'InternetGatewayDevice.DeviceInfo.ModelName':'MODEL',
'InternetGatewayDevice.DeviceInfo.ProductClass':'PRODUCT_CLASS',
'InternetGatewayDevice.DeviceInfo.SoftwareVersion':'FIRMWARE_VERSION',
'InternetGatewayDevice.DeviceInfo.UpTime':'TOTAL_UPTIME',
'InternetGatewayDevice.WANDevice.*.X_ATP_WANUMTSInterfaceConfig.IMEI':'IMEI',
'InternetGatewayDevice.WANDevice.*.X_ATP_WANUMTSInterfaceConfig.IMSI':'IMSI',
'InternetGatewayDevice.WANDevice.*.X_ATP_WANUMTSInterfaceConfig.cellID':'CELL_ID',
'InternetGatewayDevice.WANDevice.*.X_ATP_WANUMTSInterfaceConfig.eNodeBId':'ENODEB_ID',
'InternetGatewayDevice.WANDevice.*.X_ATP_WANUMTSInterfaceConfig.LAC':'LAC',
'InternetGatewayDevice.WANDevice.*.X_ATP_WANUMTSInterfaceConfig.PCI':'PCI',
'InternetGatewayDevice.WANDevice.*.X_ATP_WANUMTSInterfaceConfig.DownstreamMaxRate':'DOWNSTREAM_RATE',
'InternetGatewayDevice.WANDevice.*.X_ATP_WANUMTSInterfaceConfig.UpstreamMaxRate':'UPSTREAM_RATE',
'InternetGatewayDevice.WANDevice.*.X_ATP_WANUMTSInterfaceConfig.PLMN':'PLMN',
'InternetGatewayDevice.WANDevice.*.X_ATP_WANUMTSInterfaceConfig.RSRP':'RSRP',
'InternetGatewayDevice.WANDevice.*.X_ATP_WANUMTSInterfaceConfig.RSRQ':'RSRQ',
'InternetGatewayDevice.WANDevice.*.X_ATP_WANUMTSInterfaceConfig.RSSI':'RSSI',
'InternetGatewayDevice.WANDevice.*.X_ATP_WANUMTSInterfaceConfig.SINR':'SINR',
'InternetGatewayDevice.WANDevice.*.X_ATP_WANUMTSInterfaceConfig.SignalQuality':'SIGNAL_QUALITY',
'InternetGatewayDevice.WANDevice.*.X_ATP_WANUMTSInterfaceConfig.Stats.BytesReceived':'BYTES_RECEIVED',
'InternetGatewayDevice.WANDevice.*.X_ATP_WANUMTSInterfaceConfig.Stats.BytesSent':'BYTES_SENT',
'InternetGatewayDevice.WANDevice.*.X_ATP_WANUMTSInterfaceConfig.RoamStatus':'ROAM_STATUS',
'InternetGatewayDevice.WANDevice.*.X_ATP_WANUMTSInterfaceConfig.ServiceStatus':'SERVICE_STATUS',
'InternetGatewayDevice.WANDevice.*.WANCommonInterfaceConfig.NumberOfActiveConnections':'CONNECTED_DEVICES_WAN',
'InternetGatewayDevice.LANDevice.*.Hosts.Host.*.Active':'CONNECTED_DEVICES_LAN',
'InternetGatewayDevice.Services.X_ATP_NetworkSetting.NetworkPriority':'NETWORK_PRIORITY',
'InternetGatewayDevice.DeviceInfo.X_ATP_Antenna.AntennaStatus1':'EXTERNAL_ANTENNA1' 
#'PLACEHOLDER':'EXTERNAL_ANTENNA2' 
}

map_H89T = {    
'InternetGatewayDevice.DeviceInfo.SerialNumber':
'Serial',	
#'X':'Timestamp',
'InternetGatewayDevice.DeviceInfo.ModelName':'MODEL',	
'InternetGatewayDevice.DeviceInfo.ProductClass':'PRODUCT_CLASS',
'InternetGatewayDevice.DeviceInfo.SoftwareVersion':'FIRMWARE_VERSION',
#'PLACEHOLDER1':'TOTAL_UPTIME',
'InternetGatewayDevice.DeviceInfo.(X|Timestamp)_TGT_IMEI':'IMEI',
'InternetGatewayDevice.DeviceInfo.(X|Timestamp)_TGT_IMSI':'IMSI',
'InternetGatewayDevice.WANDevice.1.(X|Timestamp)_TGT_WANNetConfigInfo.CellId':'CELL_ID',
'InternetGatewayDevice.WANDevice.1.(X|Timestamp)_TGT_WANNetConfigInfo.EnodeBId':'ENODEB_ID',
'InternetGatewayDevice.WANDevice.1.(X|Timestamp)_TGT_WANNetConfigInfo.LAC':'LAC',
#'PLACEHOLDER2':'PCI',
'InternetGatewayDevice.WANDevice.*.WANCommonInterfaceConfig.Layer1DownstreamMaxBitRate':'DOWNSTREAM_RATE',
'InternetGatewayDevice.WANDevice.*.WANCommonInterfaceConfig.Layer1UpstreamMaxBitRate':'UPSTREAM_RATE',
'InternetGatewayDevice.WANDevice.1.(X|Timestamp)_TGT_WANNetConfigInfo.PLMN':'PLMN',
'InternetGatewayDevice.WANDevice.1.(X|Timestamp)_TGT_WANNetConfigInfo.RSRP':'RSRP',
'InternetGatewayDevice.WANDevice.1.(X|Timestamp)_TGT_WANNetConfigInfo.RSRQ':'RSRQ',
'InternetGatewayDevice.WANDevice.1.(X|Timestamp)_TGT_WANNetConfigInfo.RSSI':'RSSI',
'InternetGatewayDevice.WANDevice.1.(X|Timestamp)_TGT_WANNetConfigInfo.SINR':'SINR',
'InternetGatewayDevice.WANDevice.1.(X|Timestamp)_TGT_WANNetConfigInfo.SignalQuality':'SIGNAL_QUALITY',
'InternetGatewayDevice.LANDevice.*.WLANConfiguration.[0-9]+.TotalBytesReceived':'BYTES_RECEIVED',
#'InternetGatewayDevice.LANDevice.*.WLANConfiguration.1.TotalBytesReceived':'BYTES_RECEIVED',
'InternetGatewayDevice.LANDevice.*.WLANConfiguration.[0-9]+.TotalBytesSent':'BYTES_SENT',
#'InternetGatewayDevice.LANDevice.*.WLANConfiguration.1.TotalBytesSent':'BYTES_SENT',
'InternetGatewayDevice.WEB_GUI.LTEConfiguration.RoamingStatus':'ROAM_STATUS',	
#'PLACEHOLDER3':'SERVICE_STATUS',
'InternetGatewayDevice.WANDevice.*.WANCommonInterfaceConfig.NumberOfActiveConnections':'CONNECTED_DEVICES_WAN',
'InternetGatewayDevice.LANDevice.*.Hosts.Host.*.Active':'CONNECTED_DEVICES_LAN',
'InternetGatewayDevice.WANDevice.1.(X|Timestamp)_TGT_WANNetConfigInfo.SupportedBands':'NETWORK_PRIORITY',
'InternetGatewayDevice.WEB_GUI.LTEConfiguration.Antenna1':'EXTERNAL_ANTENNA1',
'InternetGatewayDevice.WEB_GUI.LTEConfiguration.Antenna2':'EXTERNAL_ANTENNA2'}



LTE_DEVICES = ('Y7631-42_e6','Y7631-42','Y7631-42_e7','Y689Zh-061_Yra','Y689Zh-061_OGV_SKD','Y689Zh-061_e7','Y687-060',
'Y687-060_HT','Y687-060_e7','Y684h-063','Y684h-063_OGV_Mvd','Y684h-063_OGV_LOW','Y684h-063_e4','Y684h-061_OGV','Y684h-061_e7',
'Y684h-061_e6','Y684h-061_e5','Y684h-061_e4','Y474h-34z','Y474h-34z_E7','Y464-067','Y406h-068','UzhgNrov_716Z5W','UzhgNrov_5T_894',
'H89T','H89T_e7','HVR-879T','HVR-879TG','HVR-879TH','HVR-879T_e7','EW8799','Blfdrm_I98','AOG_K78_e83.4','AOG_K74','AOG_H87_KOFH')

NO_MAPPINGS = ['6UV24886ZXZZ','ACSM S891M E7.4','AOG K74','AOG K78','NU716KOFH','I98','RTW','RTW_KIH8759Y','RTW_S4995MP','ST3754W','ST819','TZM5KG TZS','WHO4931VM(8G8I)','WHO4971VM(8G8I)','WHO4981VM','WHO4998','WHO Tzgvdzb','Y689Zh-061','ZM4493_95U8Z']



#Test
data = {'created':['2022-01-19 13:00:28'],'name':['InternetGatewayDevice.WANDevice.1.Timestamp_TGT_WANNetConfigInfo.RSRQ.active'],'productclass':['H89T'],'serial':['H89T139297956250717'],'value':['-12dBm']}

df = pd.DataFrame(data)
print(df.replace(map_H89T, regex=True).to_string())
# Out:
# /Users/cormacbracken/Projects/Incognito
#                created         name productclass               serial   value
# 0  2022-01-19 13:00:28  RSRQ.active         H89T  H89T139297956250717  -12dBm

# %%
import logging
import os
from abc import ABC

class Device(ABC):

    def __init__(self,name:str,parametermap:str):
        logging.basicConfig()
        self.log = logging.getLogger()
        #self.log.setLevel(logging.DEBUG)

        self.parametermap = parametermap
        self.name = name

    def _remove_unmapped(self,device_params:pd.DataFrame):
        # try this device_params[device_params.name.isin(parameter_defaults.keys())]
        #device_params[~device_params.name.str.contains('InternetGatewayDevice.')]
        return device_params[device_params.name.isin(parameter_defaults.keys())]

    def add_missing_parameters(self,device_params:pd.DataFrame):

        parameter_defaults_s = pd.Series(parameter_defaults.keys())

        missing_list = parameter_defaults_s[~parameter_defaults_s.isin(device_params.name)]

        for missing in missing_list:
            value = parameter_defaults.get(missing)
            new_param = pd.DataFrame({'created':[device_params.created.iloc[0]],'name':[missing],'productclass':[device_params.productclass.iloc[0]],'serial':[device_params.serial.iloc[0]],'value':[value]})
            device_params = pd.concat([device_params, new_param], ignore_index = True, axis = 0)

        return device_params

        #pd.merge(device_params,device_params.created, how="left", on=["name"])
        #parameter_defaults

    def make_mappings(self,device_params:pd.DataFrame):
        #self.log.info(f'Mapping {device_params.created.iloc[0]},{device_params.productclass.iloc[0]},{device_params.serial.iloc[0]}')

        device_params = device_params.replace(self.parametermap, regex=True)

        #device_params = self._remove_unmapped(device_params)

        return device_params

    def process_sum_active(self,device_params:pd.DataFrame,param_search_string:str)->pd.DataFrame:

        '''
        The active matches items are Summed. 
        '''
        # Find the number of connected LAN devices
        df_active  = device_params.name.str.contains(param_search_string,regex=True)
        value = (device_params[df_active].value == '1').sum()

        # create new parameter with count of devices
        new_param = pd.DataFrame({'created':[device_params.created.iloc[0]],'name':[self.parametermap[param_search_string]],'productclass':[device_params.productclass.iloc[0]],'serial':[device_params.serial.iloc[0]],'value':[value]})

        # remove all existing parameters
        device_params = device_params[~device_params.name.str.contains(param_search_string)]

        #add the new one
        device_params  = pd.concat([device_params,new_param])

        return device_params

    def process_sum(self,device_params:pd.DataFrame,param_search_string:str)->pd.DataFrame:

        '''
        The matched items values are Summed. 
        '''
        # Find the number of connected LAN devices
        df_active  = device_params.name.str.contains(param_search_string,regex=True)
        value = device_params[df_active].value.astype(int).sum()

        # create new parameter with count of devices
        new_param = pd.DataFrame({'created':[device_params.created.iloc[0]],'name':[self.parametermap[param_search_string]],'productclass':[device_params.productclass.iloc[0]],'serial':[device_params.serial.iloc[0]],'value':[value]})

        # remove all existing parameters
        device_params = device_params[~device_params.name.str.contains(param_search_string)]

        #add the new one
        device_params  = pd.concat([device_params,new_param])

        return device_params

        
        

class Device_Y687_060(Device):

    # def process_host_active(self,device_params:pd.DataFrame)->pd.DataFrame:

    #     '''
    #     Handle InternetGatewayDevice.LANDevice.*.Hosts.Host.*.Active type parameters.  The active items are Summed. 
    #     '''

    #     SEARCH:str = 'InternetGatewayDevice.LANDevice.*.Hosts.Host.*.Active'

    #     # Find the number of connected LAN devices
    #     df_active  = device_params.name.str.contains(SEARCH,regex=True)
    #     connected_devices_lan = (device_params[df_active].value == '1').sum()

    #     # create new parameter with count of devices
    #     new_param = pd.DataFrame({'created':[device_params.created.iloc[0]],'name':[self.parametermap['InternetGatewayDevice.LANDevice.*.Hosts.Host.%.Active']],'productclass':[device_params.productclass.iloc[0]],'serial':[device_params.serial.iloc[0]],'value':[connected_devices_lan]})

    #     # remove all existing parameters
    #     device_params = device_params[~device_params.name.str.contains(SEARCH)]

    #     #add the new one
    #     device_params  = pd.concat([device_params,new_param])

    #     return device_params



    def make_mappings(self,device_params:pd.DataFrame):
        self.log.info(f'Mapping {device_params.created.iloc[0]},{device_params.productclass.iloc[0]},{device_params.serial.iloc[0]}')

        #device_params = self.process_host_active(device_params)
        device_params = self.process_sum_active(device_params,param_search_string='InternetGatewayDevice.LANDevice.*.Hosts.Host.*.Active')
        
        return super().make_mappings(device_params)

class Device_H89T(Device):


    def make_mappings(self,device_params:pd.DataFrame):
        #self.log.info(f'Mapping {device_params.created.iloc[0]},{device_params.productclass.iloc[0]},{device_params.serial.iloc[0]}')

        device_params = self.process_sum(device_params,param_search_string='InternetGatewayDevice.LANDevice.*.WLANConfiguration.[0-9]+.TotalBytesReceived')
        device_params = self.process_sum(device_params,param_search_string='InternetGatewayDevice.LANDevice.*.WLANConfiguration.[0-9]+.TotalBytesSent')
        return super().make_mappings(device_params)



if __name__ == '__main__': 

    data = {'created':['2022-01-19 13:00:28','2022-01-19 13:00:28','2022-01-19 13:00:28'],
        'name':['InternetGatewayDevice.WANDevice.1.Timestamp_TGT_WANNetConfigInfo.RSRQ','InternetGatewayDevice.LANDevice.*.WLANConfiguration.1.TotalBytesReceived','InternetGatewayDevice.LANDevice.*.WLANConfiguration.2.TotalBytesReceived'],
        'productclass':['H89T','H89T','H89T'],
        'serial':['test1','H89T139297956250717','test3'],
        'value':['-12dBm','300','54']}

    
    df = pd.DataFrame(data)

    data_Y687_060 = {'created':['2022-01-19 13:00:28','2022-01-19 13:00:28'],
        'name':['InternetGatewayDevice.LANDevice.1.Hosts.Host.*.Active','InternetGatewayDevice.LANDevice.1.Hosts.Host.*.Active'],
        'productclass':['Y687_060','Y687_060'],'serial':['test1','test2'],
        'value':['1','1']}
    df_Y687_060 = pd.DataFrame(data_Y687_060)
    
    device_H89T = Device_H89T('H89T',map_H89T)
    device_Y687_060 = Device_Y687_060('Y687_060',map_Y687_060 )

    df_Y687_060 = device_Y687_060.make_mappings(df_Y687_060)
    print(device_Y687_060.add_missing_parameters(df_Y687_060).to_string())

    df = device_H89T.make_mappings(df)
    print(device_H89T.add_missing_parameters(df).to_string())
# Out:
#                 created                   name productclass serial  value
# 0   2022-01-19 13:00:28  CONNECTED_DEVICES_LAN     Y687_060  test1    2.0
# 1   2022-01-19 13:00:28                 Serial     Y687_060  test1    NaN
# 2   2022-01-19 13:00:28              Timestamp     Y687_060  test1    NaN
# 3   2022-01-19 13:00:28                  MODEL     Y687_060  test1    NaN
# 4   2022-01-19 13:00:28          PRODUCT_CLASS     Y687_060  test1    NaN
# 5   2022-01-19 13:00:28       FIRMWARE_VERSION     Y687_060  test1    NaN
# 6   2022-01-19 13:00:28           TOTAL_UPTIME     Y687_060  test1    NaN
# 7   2022-01-19 13:00:28                   IMEI     Y687_060  test1    NaN
# 8   2022-01-19 13:00:28                   IMSI     Y687_060  test1    NaN
# 9   2022-01-19 13:00:28                CELL_ID     Y687_060  test1    NaN
# 10  2022-01-19 13:00:28              ENODEB_ID     Y687_060  test1    NaN
# 11  2022-01-19 13:00:28                    LAC     Y687_060  test1    NaN
# 12  2022-01-19 13:00:28                    PCI     Y687_060  test1    NaN
# 13  2022-01-19 13:00:28        DOWNSTREAM_RATE     Y687_060  test1    NaN
# 14  2022-01-19 13:00:28          UPSTREAM_RATE     Y687_060  test1    NaN
# 15  2022-01-19 13:00:28                   PLMN     Y687_060  test1    NaN
# 16  2022-01-19 13:00:28                   RSRP     Y687_060  test1    NaN
# 17  2022-01-19 13:00:28                   RSRQ     Y687_060  test1    NaN
# 18  2022-01-19 13:00:28                   RSSI     Y687_060  test1    NaN
# 19  2022-01-19 13:00:28                   SINR     Y687_060  test1    NaN
# 20  2022-01-19 13:00:28         SIGNAL_QUALITY     Y687_060  test1    NaN
# 21  2022-01-19 13:00:28         BYTES_RECEIVED     Y687_060  test1    NaN
# 22  2022-01-19 13:00:28             BYTES_SENT     Y687_060  test1    NaN
# 23  2022-01-19 13:00:28            ROAM_STATUS     Y687_060  test1    NaN
# 24  2022-01-19 13:00:28         SERVICE_STATUS     Y687_060  test1    NaN
# 25  2022-01-19 13:00:28  CONNECTED_DEVICES_WAN     Y687_060  test1    NaN
# 26  2022-01-19 13:00:28       NETWORK_PRIORITY     Y687_060  test1    NaN
# 27  2022-01-19 13:00:28      EXTERNAL_ANTENNA1     Y687_060  test1    NaN
# 28  2022-01-19 13:00:28      EXTERNAL_ANTENNA2     Y687_060  test1    NaN
#                 created                   name productclass serial   value
# 0   2022-01-19 13:00:28                   RSRQ         H89T  test1  -12dBm
# 1   2022-01-19 13:00:28         BYTES_RECEIVED         H89T  test1     354
# 2   2022-01-19 13:00:28             BYTES_SENT         H89T  test1       0
# 3   2022-01-19 13:00:28                 Serial         H89T  test1     NaN
# 4   2022-01-19 13:00:28              Timestamp         H89T  test1     NaN
# 5   2022-01-19 13:00:28                  MODEL         H89T  test1     NaN
# 6   2022-01-19 13:00:28          PRODUCT_CLASS         H89T  test1     NaN
# 7   2022-01-19 13:00:28       FIRMWARE_VERSION         H89T  test1     NaN
# 8   2022-01-19 13:00:28           TOTAL_UPTIME         H89T  test1     NaN
# 9   2022-01-19 13:00:28                   IMEI         H89T  test1     NaN
# 10  2022-01-19 13:00:28                   IMSI         H89T  test1     NaN
# 11  2022-01-19 13:00:28                CELL_ID         H89T  test1     NaN
# 12  2022-01-19 13:00:28              ENODEB_ID         H89T  test1     NaN
# 13  2022-01-19 13:00:28                    LAC         H89T  test1     NaN
# 14  2022-01-19 13:00:28                    PCI         H89T  test1     NaN
# 15  2022-01-19 13:00:28        DOWNSTREAM_RATE         H89T  test1     NaN
# 16  2022-01-19 13:00:28          UPSTREAM_RATE         H89T  test1     NaN
# 17  2022-01-19 13:00:28                   PLMN         H89T  test1     NaN
# 18  2022-01-19 13:00:28                   RSRP         H89T  test1     NaN
# 19  2022-01-19 13:00:28                   RSSI         H89T  test1     NaN
# 20  2022-01-19 13:00:28                   SINR         H89T  test1     NaN
# 21  2022-01-19 13:00:28         SIGNAL_QUALITY         H89T  test1     NaN
# 22  2022-01-19 13:00:28            ROAM_STATUS         H89T  test1     NaN
# 23  2022-01-19 13:00:28         SERVICE_STATUS         H89T  test1     NaN
# 24  2022-01-19 13:00:28  CONNECTED_DEVICES_WAN         H89T  test1     NaN
# 25  2022-01-19 13:00:28  CONNECTED_DEVICES_LAN         H89T  test1     NaN
# 26  2022-01-19 13:00:28       NETWORK_PRIORITY         H89T  test1     NaN
# 27  2022-01-19 13:00:28      EXTERNAL_ANTENNA1         H89T  test1     NaN
# 28  2022-01-19 13:00:28      EXTERNAL_ANTENNA2         H89T  test1     NaN

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [1, 2, 3, 5]})
df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [5, 6, 7, 8]})
print(df1)
print(df2)
df1.merge(df2, left_on='lkey', right_on='rkey')
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5
#   rkey  value
# 0  foo      5
# 1  bar      6
# 2  baz      7
# 3  foo      8
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  foo        5  foo        5
# 3  foo        5  foo        8
# 4  bar        2  bar        6
# 5  baz        3  baz        7

# %%
import numpy as np
from datetime import datetime

class Devices:

    def __init__(self,parameter_data_file:str = 'DeviceParameters/Jan26_Data.txt',speed_test_data_file:str = 'SpeedTestData/2022-01-27_09-01-29-637.csv',outfile:str='device_parameter_data.csv', chunk_size:int = 100,num_chunks:int = 1,device_class:list = []):

        logging.basicConfig()
        self.log = logging.getLogger()
        self.log.setLevel(logging.INFO)

        self.parameter_data_file = parameter_data_file
        self.outfile = outfile
        self.chunk_size = chunk_size
        self.num_chunks = num_chunks
        self.device_class = device_class
        self.speed_test_data_file = speed_test_data_file

    def _remove_outfile(self):

        #remove output file
        if(os.path.exists(self.outfile) and os.path.isfile(self.outfile)):
            os.remove(self.outfile)
            self.log.info(f"{self.outfile} file deleted")
        else:
            self.log.info(f"{self.outfile} file not found")   

    def _process_parameters(self,device_params:list):
        key = (device_params.created.iloc[0],{device_params.productclass.iloc[0]},{device_params.serial.iloc[0]})
        
        self.log.debug(f'processing {device_params.created.iloc[0]},{device_params.productclass.iloc[0]},{device_params.serial.iloc[0]}')
       

        if device_params.productclass.iloc[0] == 'Y687-060':
            device_Y687_060 = Device_Y687_060('Y687_060',map_Y687_060 ) 
            device_params = device_Y687_060.make_mappings(device_params)
            
        if device_params.productclass.iloc[0] == 'H89T':
            device_H89T = Device_H89T('H89T',map_H89T)
            device_params = device_H89T.make_mappings(device_params)
            device_params = device_H89T._remove_unmapped(device_params)
            try:
                device_params = device_H89T.add_missing_parameters(device_params)
            except IndexError as e:
                self.log.error(f'{e}, key{key}:')
                #self.log.debug(f'{productclass}')
            #self.log.debug(device_H89T.add_missing_parameters(device_params).to_string())
        
        try:
            #Ignore for no mappings
            if device_params.productclass.iloc[0] in NO_MAPPINGS:
                print(f'Device {device_params.productclass.iloc[0]} has no mappings')
                #break
        except IndexError as e:
                self.log.error(f'{e}, key{key}')
                self.log.debug(f'{device_params}')

        return device_params

    def process_file(self):
        device_params = []
        devices = pd.DataFrame()
        self._remove_outfile()

        count = self.num_chunks
        start = True

        speed_test_data = pd.read_csv(self.speed_test_data_file,
            na_values = ['-'],
            dtype={'Serial': str,'Product Class':str,'Download Speed (Mbps)':float,'Time Stamp':str} )

        #speed_test_data = speed_test_data.replace(r'(^s*$)|-', float('NaN'), regex = True)

        speed_test_data = speed_test_data.dropna() 
        speed_test_data['Time Stamp'] = pd.to_datetime(speed_test_data['Time Stamp'])

        self.log.info(f'\nspeed test file {self.speed_test_data_file} stats\ncount = {speed_test_data.shape[0]}\nmin speed test date: {speed_test_data["Time Stamp"].min()}\nmax speed test date: {speed_test_data["Time Stamp"].max()}')

   
        #dateparse = lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S')

        for chunk in pd.read_csv(self.parameter_data_file, delimiter='\t',chunksize=self.chunk_size,parse_dates=['created']):

            # Get device list
            distinct = chunk[['created', 'productclass', 'serial']].drop_duplicates().reset_index()

            # loop device list
            for index, row in distinct.iterrows():

                # get the parmaeters that belong to this device
                bmask = chunk.isin({'created':[row.created],'productclass':[row.productclass],'serial':[row.serial]})

                bmask = bmask.created & bmask.productclass & bmask.serial

                # if chunk[bmask].serial.iloc[0] == 'H89T139297952837244':
                #     print('pass')

                # check for devices store accross chunks
                if len(device_params) and (index == 0)  and \
                        (device_params.created.iloc[0] == chunk[bmask].created.iloc[0])  \
                        and (device_params.productclass.iloc[0] == chunk[bmask].productclass.iloc[0])  \
                        and (device_params.serial.iloc[0] == chunk[bmask].serial.iloc[0]):

                        device_params = pd.concat([chunk[bmask],device_params])
                else:
                    device_params = chunk[bmask]

                if index == len(distinct)-1: #  skip to next chunck check for more data for this device
                    continue

                #check filter
                if device_params.productclass.iloc[0] not in self.device_class:
                    continue

                device_params = self._process_parameters(device_params)

                devices = pd.concat([devices,device_params])

            count -= 1

            if count ==0:
                break

        #self.log.info(f'{speed_test_data[speed_test_data.Serial.isin(devices.serial)]}')

        #devices['created'] = pd.to_datetime(devices['created'])
        #devices = devices.assign(Date=devices.created.dt.floor('H'))
        #speed_test_data = speed_test_data.assign(Date=speed_test_data['Time Stamp'].dt.floor('H'))

        #pd.merge_asof(devices,speed_test_data,left_on=['productclass','serial','created'], right_on = ['Product Class','Serial','Time Stamp'],direction='forwards',tolerance=pd.Timedelta('60m')).to_string()

        #merged_df = pd.merge_asof(devices.sort_values('created'),speed_test_data.sort_values('Time Stamp'),left_on=['created'],right_on = ['Time Stamp'],left_by = ['productclass','serial'],right_by = ['Product Class','Serial']
            #direction='forwards',tolerance=pd.Timedelta('60m')
         #   )

        # self.log.info(f"join speed data : {pd.merge_asof(devices,speed_test_data,left_on=['productclass','serial','created']
        #     right_on = ['Product Class','Serial','Time Stamp'],
        #     left_by = ['productclass','serial','created'],
        #     direction='forwards',tolerance=pd.Timedelta('60m')).to_string()}")

        #self.log.info(f" {speed_test_data[speed_test_data.Serial.isin(devices.serial) & (speed_test_data['Product Class'].isin(devices.productclass)) & (speed_test_data['Time Stamp'].isin(devices.created))].to_string()}")


        #devices.columns = devices.columns.to_flat_index()

        try:
            devices = devices.drop_duplicates(subset=['created', 'productclass','serial','name'])
            devices = devices.pivot(index=['created', 'productclass','serial'],columns=['name'],values=['value'])
            devices = devices.reset_index()
        except (ValueError,KeyError) as e:
            self.log.error(f'{e}')
            self.log.debug(f'{devices.to_string()}')

        #devices.columns = devices.columns.get_level_values(1)
        #flatten pivot - messy, needs review!
        columns = devices.columns.get_level_values(1).to_list()
        columns[0] = 'created'
        columns[1] = 'productclass'
        columns[2] = 'serial'
        devices.columns = columns
        
        #devices.reset_index([1, 2,3])
        #devices.columns = [' '.join(col).strip() for col in devices.columns.values]

                #devices.columns = devices.columns.to_flat_index()

        # Merge to add Target download speed
        devices_speed_test_data = pd.merge_asof(devices.sort_values('created'),speed_test_data.sort_values('Time Stamp'),
            left_on=['created'],right_on = ['Time Stamp'],
            left_by = ['productclass','serial'],right_by = ['Product Class','Serial'],
            direction='forward',tolerance=pd.Timedelta('1h'))
        
        # Remove records with no download speed
        devices_speed_test_data = devices_speed_test_data.dropna(subset=['Serial_y', 'Product Class', 'Download Speed (Mbps)','Time Stamp']).to_string())

        if start:
            devices_speed_test_data.to_csv(self.outfile, mode='a', index=False, header=True)
            start = False
        else:
            devices_speed_test_data.to_csv(self.outfile, mode='a', index=False, header=False)


        #devices.columns = devices.columns.to_flat_index()
        merged_df = pd.merge_asof(devices.sort_values('created'),speed_test_data.sort_values('Time Stamp'),
            left_on=['created'],right_on = ['Time Stamp'],
            left_by = ['productclass','serial'],right_by = ['Product Class','Serial'],
            direction='forward',tolerance=pd.Timedelta('1h'))
        
        print(merged_df.dropna(subset=['Serial_y', 'Product Class', 'Download Speed (Mbps)','Time Stamp']).to_string())



        #merged_df.dropna(subset=['Serial_y', 'Product Class', 'Download Speed (Mbps)','Time Stamp'])

        #self.log.info(f"join speed data : {devices.merge_asof(speed_test_data,left_on=['productclass','serial','Date'], right_on = ['Product Class','Serial','Date'],direction='forwards',tolerance=pd.Timedelta('60m')).to_string()}")
        #self.log.info(f" {speed_test_data[speed_test_data.Serial.isin(devices.serial) & (speed_test_data['Product Class'].isin(devices.productclass)) & (speed_test_data['Time Stamp'].isin(devices.created))].to_string()}")

if __name__ == '__main__': 
    #devices = Devices(num_chunks = 2000,device_class=['H89T'],chunk_size=1000)
    devices = Devices(parameter_data_file= 'DeviceParameters/Feb02_Data.txt',
        speed_test_data_file = 'SpeedTestData/2022-01-27_09-01-29-637.csv',
        num_chunks = 1000,device_class=['H89T'],chunk_size=2000)
    devices.process_file()
    #../SpeedTestData/2022-01-26_09-20-10-199.csv
# Out:
# INFO:root:device_parameter_data.csv file deleted
# INFO:root:
# speed test file SpeedTestData/2022-01-27_09-01-29-637.csv stats
# count = 352490
# min speed test date: 2022-01-26 01:44:00
# max speed test date: 2022-01-26 23:58:00
H89T    0,0,0,0,0,1,0,0,0  NaN  51502,51502          H89T       false   -95dBm   -6dBm   -67dBm            NaN              4   14      NaN          NaN       NaN     100000000  H89T139297957736896          H89T                  0.000 2022-01-26 14:31:00
# 3799 2022-01-26 14:27:55         H89T  H89T131201946259992              0           0  9369474-967                   NaN                     1       100000000   9369474          External          External      H89T_7.89.8  131201946259992  484974376014801   32  H89T    0,0,0,0,0,1,0,0,0  NaN  51502,51502          H89T       false   -87dBm   -7dBm   -57dBm            NaN              4   15      NaN          NaN       NaN     100000000  H89T131201946259992          H89T                 15.090 2022-01-26 14:29:00
# 3833 2022-01-26 14:28:07         H89T  H89T139297959493025              0           0  9662267-936                   NaN                     1       100000000   9662267          Built-in          External      H89T_7.89.8  139297959493025  484974388469802   63  H89T  4,0,0,8,128,1,0,0,0  NaN  51502,51502          H89T       false  -104dBm   -9dBm   -84dBm            NaN              3    9      NaN          NaN       NaN     100000000  H89T139297959493025          H89T                  0.000 2022-01-26 14:30:00
# 3836 2022-01-26 14:28:07         H89T  H89T139297952998723              0           0  9661943-966                   NaN                     1       100000000   9661943          External          External      H89T_7.89.8  139297952998723  484974377551232   33  H89T  4,0,0,8,128,1,0,0,0  NaN  51502,51502          H89T       false   -85dBm  -10dBm   -53dBm            NaN              5   19      NaN          NaN       NaN     100000000  H89T139297952998723          H89T                  0.000 2022-01-26 14:30:00
# 3965 2022-01-26 14:29:59         H89T  H89T139297954305133              0           0  9669523-998                   NaN                     1       100000000   9669523          External          External      H89T_7.89.8  139297954305133  484974377464542    1  H89T      4,0,0,0,0,0,0,0  NaN  51502,51502          H89T       false   -88dBm   -9dBm   -63dBm            NaN              4   15      NaN          NaN       NaN     100000000  H89T139297954305133          H89T                  0.000 2022-01-26 14:31:00

# %%
import unittest

class TestNotebook(unittest.TestCase):
    
    def test_add(self):
        self.assertEqual(add(2, 2), 5)
        

unittest.main(argv=[''], verbosity=2, exit=False)

# %%
#https://medium.com/analytics-vidhya/how-python-handles-big-files-fc60ff90b819

# import required modulesclear
import zipfile
import pandas as pd
import dask.dataframe as dd
from tqdm import tqdm


# # open zipped dataset

with zipfile.ZipFile(zipfile1, 'r') as z:
  with z.open("Jan26_Data.txt") as f:

    #https://towardsdatascience.com/4-tricks-you-should-know-to-parse-date-columns-with-pandas-read-csv-27355bb2ad0e
    chunk_data = pd.read_csv(f,sep="\t",chunksize=100000,parse_dates=['created'], 
            dayfirst=True)


    #data = dd.read_csv(f,sep="\t")
    #data = pd.read_csv(f,sep="\t")

    n=0

    Y474h_34z = []
    for count, chunk in enumerate(tqdm(chunk_data)):
    #for chunk in chunk_data:
      
        #print(count)
        #df_filtered = chunk
        df_filtered = chunk[chunk['created'].dt.strftime('%d-%m-%Y') == '23-01-2022']
        #print(df_filtered)
        #print(chunk['created'].dt.strftime('%d-%m-%Y'))
        Y474h_34z.append(df_filtered[df_filtered.productclass=='Y474h-34z'])
        #print(Y474h_34z)
        #Y474h_34z.append(chunk[chunk.created=='2022-01-19 13:00:36'])
        #break
        print

    print(Y474h_34z)

        #print(chunk.productclass)



        # if n == 0:
        #     need_data.to_csv("orders_filter.txt",index=None)
        #     n+=1

        # else:
        #     need_data.to_csv("orders_filter.txt",index=None,mode='a',header=None)
# Out:
# [Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# ...
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: [], Empty DataFrame
# Columns: [created, name, productclass, serial, value]
# Index: []]
